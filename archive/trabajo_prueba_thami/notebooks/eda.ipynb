# %% [markdown]
# # Exploratory Data Analysis (EDA) - Airlines Dataset
#
# ## 1. Introducción
# Este notebook tiene como objetivo entender la estructura del dataset, limpiar los datos y explorar relaciones entre variables y la satisfacción del cliente.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración visual
sns.set(style="whitegrid")
# %matplotlib inline

# %% [markdown]
# ## 2. Carga de Datos

# %%
# TODO: Cargar dataset
# data_path = '../data/raw/airlines.csv'
# df = pd.read_csv(data_path)
# df.head()

# %% [markdown]
# ## 3. Análisis General

# %%
# TODO: Revisar info, nulos y estadísticos
# df.info()
# df.describe()

# %% [markdown]
# ## 4. Visualización de Variables

# %%
# TODO: Histogramas y correlaciones
